# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivanov-666/ML/blob/main/%D0%A2%D0%90%D0%94_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

# %%
df = pd.read_csv("/weatherAUS.csv", sep=",")
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
numeric_cols = ["MinTemp",
                "MaxTemp",
                "Rainfall",
                "Evaporation",
                "Sunshine",
                "WindGustSpeed",
                "WindSpeed9am",
                "WindSpeed3pm",
                "Humidity9am",
                "Humidity3pm",
                "Pressure9am",
                "Pressure3pm",
                "Cloud9am",
                "Cloud3pm",
                "Temp9am",
                "Temp3pm"]
df_num = df[numeric_cols].dropna()
ax, fig = plt.subplots(figsize=[16,9])
sns.heatmap(df_num.corr(),  annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Видим, что есть мультиколлениартные признаки, они могут помешать дальнейшему обучению моделей

# %%
df = df.drop(["Pressure3pm","Temp9am","Temp3pm", "Evaporation","Sunshine","Cloud9am", "Cloud3pm"], axis=1)

# %%
df.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
numeric_cols.remove("Pressure3pm")
numeric_cols.remove("Temp9am")
numeric_cols.remove("Temp3pm")
numeric_cols.remove("Sunshine")
numeric_cols.remove("Cloud3pm")
numeric_cols.remove("Cloud9am")
numeric_cols.remove("Evaporation")

# %%
for col_name in numeric_cols:
  df[col_name] = df[col_name].fillna(df[col_name].mean())

# %%
df.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df["Date"] = df["Date"].astype("datetime64[ns]")
df["Day"] = df["Date"].dt.day
df["Month"]= df["Date"].dt.month
df["Year"] = df["Date"].dt.year
df = df.drop(["Date"], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
df["Location"] = LabelEncoder().fit_transform(df.Location)

# %%
df["WindGustDir"].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', nan, 'ENE',
#        'SSE', 'S', 'NW', 'SE', 'ESE', 'E', 'SSW'], dtype=object)

# %%
df["WindDir9am"].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
df["WindDir3pm"].unique()
# Out:
# array(['WNW', 'WSW', 'E', 'NW', 'W', 'SSE', 'ESE', 'ENE', 'NNW', 'SSW',
#        'SW', 'SE', 'N', 'S', 'NNE', nan, 'NE'], dtype=object)

# %%
cols = ["WindGustDir","WindDir9am","WindDir3pm"]
for col in cols:
  df[col] = df[col].fillna(df[col].mode())
#df = pd.get_dummies(data=df, prefix=cols, prefix_sep="_", columns=cols)

# %%
df["WindGustDir"] = LabelEncoder().fit_transform(df.WindGustDir)
df["WindDir3pm"] = LabelEncoder().fit_transform(df.WindDir3pm)
df["WindDir9am"] = LabelEncoder().fit_transform(df.WindDir9am)

# %%
df["RainToday"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["RainTomorrow"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
cols_bool = ["RainToday", "RainTomorrow"]
for col in cols_bool:
  df[col] = df[col].map({'Yes': 1, 'No': 0})
  df[col] = df[col].fillna(df[col].mode()[0])

# %%
df["RainToday"].unique()
# Out:
# array([0., 1.])

# %%
df["RainTomorrow"].unique()
# Out:
# array([0., 1.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       145460 non-null  int64
#  1   MinTemp        145460 non-null  float64
#  2   MaxTemp        145460 non-null  float64
#  3   Rainfall       145460 non-null  float64
#  4   WindGustDir    145460 non-null  int64
#  5   WindGustSpeed  145460 non-null  float64
#  6   WindDir9am     145460 non-null  int64
#  7   WindDir3pm     145460 non-null  int64
#  8   WindSpeed9am   145460 non-null  float64
#  9   WindSpeed3pm   145460 non-null  float64
#  10  Humidity9am    145460 non-null  float64
#  11  Humidity3pm    145460 non-null  float64
#  12  Pressure9am    145460 non-null  float64
#  13  RainToday      145460 non-null  float64
#  14  RainTomorrow   145460 non-null  float64
#  15  Day            145460 non-null  int64
#  16  Month          145460 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# RainToday        0
# RainTomorrow     0
# Day              0
# Month            0
# Year             0
# dtype: int64

# %%
df.to_csv("/content/drive/MyDrive/weather_AUS_preprocessed.csv", encoding="utf-8", sep=';', index=False)

# %%
df.hist(bins=10, figsize=(25, 20))
# Out:
# array([[<Axes: title={'center': 'Location'}>,
#         <Axes: title={'center': 'MinTemp'}>,
#         <Axes: title={'center': 'MaxTemp'}>,
#         <Axes: title={'center': 'Rainfall'}>],
#        [<Axes: title={'center': 'WindGustDir'}>,
#         <Axes: title={'center': 'WindGustSpeed'}>,
#         <Axes: title={'center': 'WindDir9am'}>,
#         <Axes: title={'center': 'WindDir3pm'}>],
#        [<Axes: title={'center': 'WindSpeed9am'}>,
#         <Axes: title={'center': 'WindSpeed3pm'}>,
#         <Axes: title={'center': 'Humidity9am'}>,
#         <Axes: title={'center': 'Humidity3pm'}>],
#        [<Axes: title={'center': 'Pressure9am'}>,
#         <Axes: title={'center': 'RainToday'}>,
#         <Axes: title={'center': 'RainTomorrow'}>,
#         <Axes: title={'center': 'Day'}>],
#        [<Axes: title={'center': 'Month'}>,
#         <Axes: title={'center': 'Year'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# Моделирование

# %%
df_cv = df.sample(10000)
y_cv = df_cv['RainTomorrow']
X_cv = df_cv.drop(columns = ['RainTomorrow'])
y = df['RainTomorrow']
X = df.drop(columns = ['RainTomorrow'])

# %%
from sklearn.model_selection import train_test_split
X_train_cv, X_test_cv, y_train_cv, y_test_cv = train_test_split(X_cv, y_cv, stratify=y_cv, test_size=0.2)
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_cv = scaler.fit_transform(X_train_cv)
X_test_cv = scaler.transform(X_test_cv)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
parameters = {'n_neighbors': [3, 5, 7, 9]}

knn_optimal = GridSearchCV(KNeighborsClassifier(), parameters).fit(X_train_cv, y_train_cv)
knn_optimal.best_params_
# Out:
# {'n_neighbors': 9}

# %%
knn = KNeighborsClassifier(knn_optimal.best_params_['n_neighbors']).fit(X_train, y_train)

# %%
knn_pred = knn.predict(X_test)

# %%
print(classification_report(y_test, knn_pred))
print(confusion_matrix(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.95      0.90     22717
#          1.0       0.71      0.41      0.52      6375
#
#     accuracy                           0.83     29092
#    macro avg       0.78      0.68      0.71     29092
# weighted avg       0.82      0.83      0.82     29092
#
# [[21627  1090]
#  [ 3731  2644]]

# %%
parameters = {'C': np.arange(0.1, 1, 0.1), 'penalty' : ['l1','l2']}
lr_optimal = GridSearchCV(LogisticRegression(solver='liblinear'), parameters).fit(X_train_cv, y_train_cv)
lr_optimal.best_params_
# Out:
# {'C': 0.9, 'penalty': 'l1'}

# %%
lr = LogisticRegression(C = lr_optimal.best_params_['C'], penalty = lr_optimal.best_params_['penalty'], solver = 'liblinear').fit(X_train, y_train)

# %%
lr_pred = lr.predict(X_test)

# %%
print(classification_report(y_test, lr_pred))
print(confusion_matrix(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90     22717
#          1.0       0.71      0.45      0.55      6375
#
#     accuracy                           0.84     29092
#    macro avg       0.78      0.70      0.73     29092
# weighted avg       0.83      0.84      0.83     29092
#
# [[21528  1189]
#  [ 3493  2882]]

# %%
parameters = {'max_depth': [3,5,7,9]}
dt_optimal = GridSearchCV(DecisionTreeClassifier(), parameters).fit(X_train_cv, y_train_cv)
dt_optimal.best_params_
# Out:
# {'max_depth': 3}

# %%
dt = DecisionTreeClassifier(max_depth = dt_optimal.best_params_['max_depth']).fit(X_train, y_train)

# %%
dt_pred = dt.predict(X_test)

# %%
print(classification_report(y_test, dt_pred))
print(confusion_matrix(y_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.96      0.90     22717
#          1.0       0.72      0.37      0.49      6375
#
#     accuracy                           0.83     29092
#    macro avg       0.78      0.67      0.70     29092
# weighted avg       0.82      0.83      0.81     29092
#
# [[21793   924]
#  [ 3988  2387]]

# %%
parameters = {'n_estimators': [100, 200, 300, 400]}
bag_optimal = GridSearchCV(BaggingClassifier(estimator = DecisionTreeClassifier(max_depth = 5)), parameters).fit(X_train_cv, y_train_cv)
bag_optimal.best_params_
# Out:
# {'n_estimators': 400}

# %%
bag = BaggingClassifier(estimator = DecisionTreeClassifier(max_depth = 5), n_estimators = bag_optimal.best_params_['n_estimators']).fit(X_train, y_train)
bag_pred = bag.predict(X_test)

# %%
print(classification_report(y_test, bag_pred))
print(confusion_matrix(y_test, bag_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.96      0.90     22717
#          1.0       0.74      0.41      0.53      6375
#
#     accuracy                           0.84     29092
#    macro avg       0.80      0.69      0.72     29092
# weighted avg       0.83      0.84      0.82     29092
#
# [[21811   906]
#  [ 3745  2630]]

# %%
import tensorflow as tf

# %%
X.shape[1]
# Out:
# 114

# %%
model_classification_1 = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(256, activation="relu", input_shape=(114,)),
        tf.keras.layers.Dense(256, activation="relu"),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(16, activation="relu"),
        tf.keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model_classification_1.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss="binary_crossentropy")
model_classification_1.fit(X_train_cv, y_train_cv, epochs=35)
# Out:
# Epoch 1/35
# 250/250 [==============================] - 3s 5ms/step - loss: 0.4001
# Epoch 2/35
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3518
# Epoch 3/35
# 250/250 [==============================] - 2s 8ms/step - loss: 0.3302
# Epoch 4/35
# 250/250 [==============================] - 2s 8ms/step - loss: 0.3108
# Epoch 5/35
# 250/250 [==============================] - 2s 6ms/step - loss: 0.2925
# Epoch 6/35
# 250/250 [==============================] - 1s 5ms/step - loss: 0.2597
# Epoch 7/35
# 250/250 [==============================] - 1s 5ms/step - loss: 0.2410
# Epoch 8/35
# 250/250 [==============================] - 1s 5ms/step - loss: 0.2194
# Epoch 9/35
# 250/250 [==============================] - 1s 5ms/step - loss: 0.1930
# Epoch 10/35
# 250/250 [==============================] - 1s 5ms/step - loss: 0.1829
# Epoch 11/35
# 250/250 [==============================] - 1s 5ms/step - loss: 0.1617
# Epoch 12/35
# ...

# %%
nn_pred = np.around(model_classification_1.predict(X_test))
# Out:
# 910/910 [==============================] - 2s 2ms/step

# %%
print(classification_report(y_test, nn_pred))
print(confusion_matrix(y_test, nn_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89     22717
#          1.0       0.62      0.53      0.57      6375
#
#     accuracy                           0.83     29092
#    macro avg       0.75      0.72      0.73     29092
# weighted avg       0.82      0.83      0.82     29092
#
# [[20680  2037]
#  [ 2997  3378]]

# %% [markdown]
# Лучше всего себя показала логистическая регрессия, сохраним эту модель для применения в дашборде

# %%
import pickle
pickle.dump(lr, open('/content/drive/MyDrive/log_regress.sav', 'wb'))

# %% [markdown]
# Ссылка на репозиторий со Streamlit приложением
# https://github.com/Ivanov-666/TAD_Streamlit_app
